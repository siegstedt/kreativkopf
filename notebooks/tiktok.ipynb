# %% [markdown]
# # How to work with the TikTok API?
#
# check this package
# https://github.com/davidteather/TikTok-Api
#
# check the docs
# https://davidteather.github.io/TikTok-Api/docs/index.html
