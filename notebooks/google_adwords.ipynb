# %% [markdown]
# # How to call the Google Adwords API for retrieving information on your Marketing campaign?
#
# Guide on getting started with the Google AdWords API:
# https://developers.google.com/adwords/api/docs/guides/start

# %%
# intall google ads via pip
#!pip install googleads
# Out:
# Collecting googleads
#   Downloading googleads-27.0.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 41 kB/s  eta 0:00:011
# Collecting google-auth<2.0.0,>=1.0.0
#   Downloading google_auth-1.28.0-py2.py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 77 kB/s eta 0:00:01
# Collecting google-auth-oauthlib<1.0.0,>=0.0.1
#   Downloading google_auth_oauthlib-0.4.3-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from googleads) (2021.1)
# Collecting PyYAML<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp39-cp39-macosx_10_9_x86_64.whl (259 kB)
#      |████████████████████████████████| 259 kB 253 kB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from googleads) (2.25.1)
# Collecting xmltodict<1.0.0,>=0.9.2
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting zeep>=2.5.0
#   Downloading zeep-4.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 80 kB/s eta 0:00:01
# Requirement already satisfied: setuptools>=40.3.0 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from google-auth<2.0.0,>=1.0.0->googleads) (52.0.0.post20210125)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from google-auth<2.0.0,>=1.0.0->googleads) (1.15.0)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->googleads) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->googleads) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->googleads) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->googleads) (1.26.3)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting appdirs>=1.4.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 130 kB/s eta 0:00:01
# Requirement already satisfied: defusedxml>=0.4.1 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from zeep>=2.5.0->googleads) (0.7.1)
# Collecting requests-file>=1.5.1
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: attrs>=17.2.0 in /opt/anaconda3/envs/kreativkopf/lib/python3.9/site-packages (from zeep>=2.5.0->googleads) (20.3.0)
# Collecting cached-property>=1.3.0
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting requests-toolbelt>=0.7.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 118 kB/s eta 0:00:01
# Collecting lxml>=3.1.0
#   Downloading lxml-4.6.3-cp39-cp39-macosx_10_9_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 75 kB/s eta 0:00:018
# Building wheels for collected packages: googleads
#   Building wheel for googleads (setup.py) ... done
#   Created wheel for googleads: filename=googleads-27.0.0-py3-none-any.whl size=46328 sha256=96b16e193eda0e650b8e6b13bb50348c7cf6bb9eee5d37847d42a563e4db37c4
#   Stored in directory: /Users/siegstedt/Library/Caches/pip/wheels/e2/b2/b8/4d73dfa5f188fed564125c5be376bcf121a6d2a3cbe88d3997
# Successfully built googleads
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-toolbelt, requests-oauthlib, requests-file, lxml, isodate, google-auth, cached-property, appdirs, zeep, xmltodict, PyYAML, google-auth-oauthlib, googleads
# Successfully installed PyYAML-5.4.1 appdirs-1.4.4 cached-property-1.5.2 cachetools-4.2.1 google-auth-1.28.0 google-auth-oauthlib-0.4.3 googleads-27.0.0 isodate-0.6.0 lxml-4.6.3 oauthlib-3.1.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-file-1.5.1 requests-oauthlib-1.3.0 requests-toolbelt-0.9.1 rsa-4.7.2 xmltodict-0.12.0 zeep-4.0.0

# %%
# google dev token
token = "zHvHdSKGj1FB6RWQaeyEvg"

# %% [markdown]
# Good that we have the dev token. But we still need more. E.g. **user_agent, client_customer_id, client_id, client_secret, refresh_token**.
#
#
# Steps to follow **after the developer token** was provided:
# https://developers.google.com/adwords/api/docs/guides/first-api-call#create_test_accounts
#
# Setup **API access on behalf of clients**:
# https://github.com/googleads/googleads-python-lib/wiki/API-access-on-behalf-of-your-clients-(web-flow)

# %% [markdown]
# ### get keyword traffic estimation
#
# https://developers.google.com/adwords/api/docs/samples/python/optimization#get-keyword-traffic-estimates
#
# This example retrieves keyword traffic estimates.
#
# The LoadFromStorage method is pulling credentials and properties from a "googleads.yaml" file. By default, it looks for this file in your home directory.

# %%
from googleads import adwords
