# %% [markdown]
# # How to call the Google AdWords API for retrieving information on your Marketing campaign?

# %% [markdown]
# ## Getting started with Google AdWords
#
# Well, we're pretty lucky that Google takes care of their developer friends, and so they create extensive documentation pages for the software they craft.
#
# https://developers.google.com/adwords/api/docs/guides/start
#
# Look up this page for getting just about any information on the Google AdWords API.
#
# That would include such steps as requesting a developer token, creating a test account at MCC (My Client Center), set up oauth2 authentification.

# %% [markdown]
# ### Run some basic operations
#
# https://developers.google.com/adwords/api/docs/samples/python/basic-operations

# %% [markdown]
# ### Campaign management
#
# https://developers.google.com/adwords/api/docs/samples/php/campaign-management

# %% [markdown]
# ### Reporting

# %% [markdown]
# ### Targeting

# %% [markdown]
# ### Remarketing

# %% [markdown]
# ### Optimization
